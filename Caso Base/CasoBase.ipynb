# %%
# !apt-get install -y coinor-cbc
# !pip install pyomo
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: pyomo in c:\users\marianalozano\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.9.2)
# Requirement already satisfied: ply in c:\users\marianalozano\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyomo) (3.11)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\MarianaLozano\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from pyomo.environ import *

# === 1. Cargar datos ===
clients_df = pd.read_csv('Datos/clients.csv')
depots_df = pd.read_csv('Datos/depots.csv')
vehicles_df = pd.read_csv('Datos/vehicles.csv')

# Conjuntos
D = ['MUN' + str(int(i)).zfill(2) for i in clients_df['LocationID']]
P = ['PTO' + str(int(i)).zfill(2) for i in depots_df['LocationID']]
V_set = list(vehicles_df['VehicleID'].astype(str))
N = P + D

# === Coordenadas ===
coords = {}

# Depot (ya está bien tu CSV ahora 💪)
for _, row in depots_df.iterrows():
    key = 'PTO' + str(int(row['LocationID'])).zfill(2)
    lat = float(row['Latitude'])
    lon = float(row['Longitude'])
    coords[key] = (lat, lon)
    print(f"[DEPOT] {key}: ({lat}, {lon})")

# Clientes
for _, row in clients_df.iterrows():
    key = 'MUN' + str(int(row['LocationID'])).zfill(2)
    lat = float(row['Latitude'])
    lon = float(row['Longitude'])
    coords[key] = (lat, lon)
    print(f"[CLIENT] {key}: ({lat}, {lon})")


# === 2. Calcular distancias (Haversine) ===
from math import radians, sin, cos, sqrt, atan2

def haversine(coord1, coord2):
    R = 6371  # km
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

dist = {}
for i in N:
    for j in N:
        if i != j:
            dist[(i, j)] = haversine(coords[i], coords[j])
            print(f"Distancia {i} -> {j}: {dist[(i, j)]:.2f} km")

# === Parámetros ===
Ft = 5000    # Tarifa flete COP/km
Cm = 700     # Mantenimiento COP/km

# Capacidad y autonomía
Q = dict(zip(vehicles_df['VehicleID'].astype(str), vehicles_df['Capacity']))
Autonomy = dict(zip(vehicles_df['VehicleID'].astype(str), vehicles_df['Range']))

# Demanda
demand = {}
for _, row in clients_df.iterrows():
    key = 'MUN' + str(int(row['LocationID'])).zfill(2)
    demand[key] = row['Demand']


# === 3. Modelo Pyomo ===
model = ConcreteModel()

# Sets
model.V = Set(initialize=V_set)
model.N = Set(initialize=N)
model.D = Set(initialize=D)

# Variables
model.x = Var(model.V, model.N, model.N, domain=Binary)
model.q = Var(model.V, model.D, domain=NonNegativeReals)

# === 4. Función objetivo ===
def total_cost_rule(m):
    return sum(
        (Ft * dist[i, j] + Cm * dist[i, j]) * m.x[v, i, j]
        for v in m.V for i in m.N for j in m.N if i != j
    )
model.TotalCost = Objective(rule=total_cost_rule, sense=minimize)

# === 5. Restricciones ===

# (R1) Cada cliente es visitado una vez
def one_visit_per_client_rule(m, j):
    return sum(m.x[v, i, j] for v in m.V for i in m.N if i != j) == 1
model.VisitOnce = Constraint(model.D, rule=one_visit_per_client_rule)

# (R2) Conservación de flujo
def flow_conservation_rule(m, v, k):
    return sum(m.x[v, i, k] for i in m.N if i != k) == sum(m.x[v, k, j] for j in m.N if j != k)
model.FlowConservation = Constraint(model.V, model.N, rule=flow_conservation_rule)

# (R3) Capacidad de vehículo
def capacity_rule(m, v):
    return sum(m.q[v, j] for j in m.D) <= Q[v]
model.Capacity = Constraint(model.V, rule=capacity_rule)

# (R4) Satisfacer la demanda si visita
def demand_delivery_rule(m, v, j):
    return m.q[v, j] <= demand[j] * sum(m.x[v, i, j] for i in m.N if i != j)
model.DemandDelivery = Constraint(model.V, model.D, rule=demand_delivery_rule)

# (R5) Autonomía del vehículo (opcional pero recomendado)
def autonomy_rule(m, v):
    return sum(dist[i, j] * m.x[v, i, j] for i in m.N for j in m.N if i != j) <= Autonomy[v]
model.Autonomy = Constraint(model.V, rule=autonomy_rule)

# (R6) Los vehículos deben salir del depósito
def start_from_depot_rule(m, v):
    return sum(m.x[v, i, j] for i in P for j in m.N if i != j) == 1
model.StartFromDepot = Constraint(model.V, rule=start_from_depot_rule)

# (R7) Los vehículos deben regresar al depósito
def return_to_depot_rule(m, v):
    return sum(m.x[v, i, j] for i in m.N for j in P if i != j) == 1
model.ReturnToDepot = Constraint(model.V, rule=return_to_depot_rule)

# === Resolver ===
solver = SolverFactory('glpk', executable='glpk-4.65\\w64\\glpsol.exe')
results = solver.solve(model, tee=True)

# === Mostrar resultados ===
if results.solver.status == SolverStatus.ok:
    print("\n¡Solución encontrada!")
    total_cost = model.TotalCost()
    print(f"Costo total: ${total_cost:.2f} COP")
    
    for v in model.V:
        route = []
        current = None
        
        # Encuentra el nodo de inicio (depósito)
        for i in P:
            for j in model.N:
                if i != j and value(model.x[v, i, j]) > 0.5:
                    route.append(i)
                    current = j
                    break
            if current:
                break
        
        # Si no hay ruta para este vehículo, continuar
        if not current:
            continue
            
        # Recorrer la ruta
        while current not in P:
            route.append(current)
            for j in model.N:
                if current != j and value(model.x[v, current, j]) > 0.5:
                    current = j
                    break
        
        route.append(current)  # Añadir el retorno al depósito
        
        # Calcular distancia y carga
        total_distance = sum(dist[route[i], route[i+1]] for i in range(len(route)-1))
        total_load = sum(demand.get(node, 0) for node in route if node in D)
        
        print(f"\nRuta del vehículo {v}:")
        print(" -> ".join(route))
        print(f"Distancia total: {total_distance:.2f} km")
        print(f"Carga total: {total_load} unidades")
        
        # Mostrar entregas detalladas
        print("Detalle de entregas:")
        for node in route:
            if node in D:
                delivered = value(model.q[v, node])
                if delivered > 0:
                    print(f"  {node}: {delivered} unidades")
else:
    print("No se encontró una solución factible.")
# Out:
# [DEPOT] PTO01: (4.743359, -74.153536)
# [CLIENT] MUN02: (4.59795431125545, -74.09893796560621)
# [CLIENT] MUN03: (4.687820646838871, -74.07557103763986)
# [CLIENT] MUN04: (4.70949446000624, -74.10708524062704)
# [CLIENT] MUN05: (4.605029068682624, -74.09727965657427)
# [CLIENT] MUN06: (4.648463876533332, -74.16464148202755)
# [CLIENT] MUN07: (4.662137416953968, -74.12083799988112)
# [CLIENT] MUN08: (4.697499030379109, -74.02213076607309)
# [CLIENT] MUN09: (4.649416884236942, -74.17207549744595)
# [CLIENT] MUN10: (4.606310650273935, -74.15615257246444)
# [CLIENT] MUN11: (4.557379705282216, -74.09041145358674)
# [CLIENT] MUN12: (4.591594072172954, -74.17802255204528)
# [CLIENT] MUN13: (4.7564172406324055, -74.1015410917749)
# [CLIENT] MUN14: (4.646217006050524, -74.09690889182339)
# [CLIENT] MUN15: (4.725912125314368, -74.1219200708342)
# [CLIENT] MUN16: (4.604168478560718, -74.0942948461378)
# [CLIENT] MUN17: (4.557320898243896, -74.11138839002187)
# [CLIENT] MUN18: (4.615869066082658, -74.12463941285208)
# [CLIENT] MUN19: (4.656402930181292, -74.12456164551857)
# [CLIENT] MUN20: (4.706188309535041, -74.04990580408855)
# [CLIENT] MUN21: (4.746624762561149, -74.121866801394)
# [CLIENT] MUN22: (4.746517184687941, -74.02454895778163)
# [CLIENT] MUN23: (4.625425626584072, -74.08683592702927)
# [CLIENT] MUN24: (4.731406773645735, -74.11652648751144)
# [CLIENT] MUN25: (4.577489966973782, -74.12629327283491)
# Distancia PTO01 -> MUN02: 17.26 km
# Distancia PTO01 -> MUN03: 10.62 km
# Distancia PTO01 -> MUN04: 6.38 km
# Distancia PTO01 -> MUN05: 16.60 km
# Distancia PTO01 -> MUN06: 10.62 km
# Distancia PTO01 -> MUN07: 9.73 km
# Distancia PTO01 -> MUN08: 15.43 km
# Distancia PTO01 -> MUN09: 10.65 km
# Distancia PTO01 -> MUN10: 15.24 km
# Distancia PTO01 -> MUN11: 21.83 km
# Distancia PTO01 -> MUN12: 17.09 km
# Distancia PTO01 -> MUN13: 5.94 km
# Distancia PTO01 -> MUN14: 12.49 km
# Distancia PTO01 -> MUN15: 4.00 km
# Distancia PTO01 -> MUN16: 16.81 km
# Distancia PTO01 -> MUN17: 21.21 km
# Distancia PTO01 -> MUN18: 14.53 km
# Distancia PTO01 -> MUN19: 10.19 km
# Distancia PTO01 -> MUN20: 12.21 km
# Distancia PTO01 -> MUN21: 3.53 km
# Distancia PTO01 -> MUN22: 14.30 km
# Distancia PTO01 -> MUN23: 15.05 km
# Distancia PTO01 -> MUN24: 4.31 km
# Distancia PTO01 -> MUN25: 18.69 km
# Distancia MUN02 -> PTO01: 17.26 km
# Distancia MUN02 -> MUN03: 10.32 km
# Distancia MUN02 -> MUN04: 12.44 km
# Distancia MUN02 -> MUN05: 0.81 km
# Distancia MUN02 -> MUN06: 9.20 km
# Distancia MUN02 -> MUN07: 7.54 km
# Distancia MUN02 -> MUN08: 13.96 km
# Distancia MUN02 -> MUN09: 9.92 km
# Distancia MUN02 -> MUN10: 6.41 km
# Distancia MUN02 -> MUN11: 4.61 km
# Distancia MUN02 -> MUN12: 8.79 km
# Distancia MUN02 -> MUN13: 17.62 km
# Distancia MUN02 -> MUN14: 5.37 km
# Distancia MUN02 -> MUN15: 14.45 km
# Distancia MUN02 -> MUN16: 0.86 km
# Distancia MUN02 -> MUN17: 4.72 km
# Distancia MUN02 -> MUN18: 3.48 km
# Distancia MUN02 -> MUN19: 7.09 km
# Distancia MUN02 -> MUN20: 13.21 km
# Distancia MUN02 -> MUN21: 16.73 km
# Distancia MUN02 -> MUN22: 18.46 km
# Distancia MUN02 -> MUN23: 3.34 km
# Distancia MUN02 -> MUN24: 14.97 km
# Distancia MUN02 -> MUN25: 3.79 km
# Distancia MUN03 -> PTO01: 10.62 km
# Distancia MUN03 -> MUN02: 10.32 km
# Distancia MUN03 -> MUN04: 4.24 km
# Distancia MUN03 -> MUN05: 9.52 km
# Distancia MUN03 -> MUN06: 10.80 km
# Distancia MUN03 -> MUN07: 5.77 km
# Distancia MUN03 -> MUN08: 6.02 km
# Distancia MUN03 -> MUN09: 11.52 km
# Distancia MUN03 -> MUN10: 12.72 km
# Distancia MUN03 -> MUN11: 14.60 km
# Distancia MUN03 -> MUN12: 15.60 km
# Distancia MUN03 -> MUN13: 8.15 km
# Distancia MUN03 -> MUN14: 5.20 km
# Distancia MUN03 -> MUN15: 6.66 km
# Distancia MUN03 -> MUN16: 9.53 km
# Distancia MUN03 -> MUN17: 15.04 km
# Distancia MUN03 -> MUN18: 9.67 km
# Distancia MUN03 -> MUN19: 6.46 km
# Distancia MUN03 -> MUN20: 3.50 km
# Distancia MUN03 -> MUN21: 8.31 km
# Distancia MUN03 -> MUN22: 8.64 km
# Distancia MUN03 -> MUN23: 7.05 km
# Distancia MUN03 -> MUN24: 6.64 km
# Distancia MUN03 -> MUN25: 13.49 km
# Distancia MUN04 -> PTO01: 6.38 km
# Distancia MUN04 -> MUN02: 12.44 km
# Distancia MUN04 -> MUN03: 4.24 km
# Distancia MUN04 -> MUN05: 11.67 km
# Distancia MUN04 -> MUN06: 9.31 km
# Distancia MUN04 -> MUN07: 5.48 km
# Distancia MUN04 -> MUN08: 9.51 km
# Distancia MUN04 -> MUN09: 9.82 km
# Distancia MUN04 -> MUN10: 12.70 km
# Distancia MUN04 -> MUN11: 17.02 km
# Distancia MUN04 -> MUN12: 15.29 km
# Distancia MUN04 -> MUN13: 5.25 km
# Distancia MUN04 -> MUN14: 7.13 km
# Distancia MUN04 -> MUN15: 2.46 km
# Distancia MUN04 -> MUN16: 11.80 km
# Distancia MUN04 -> MUN17: 16.93 km
# Distancia MUN04 -> MUN18: 10.59 km
# Distancia MUN04 -> MUN19: 6.21 km
# Distancia MUN04 -> MUN20: 6.35 km
# Distancia MUN04 -> MUN21: 4.44 km
# Distancia MUN04 -> MUN22: 10.03 km
# Distancia MUN04 -> MUN23: 9.61 km
# Distancia MUN04 -> MUN24: 2.65 km
# Distancia MUN04 -> MUN25: 14.83 km
# Distancia MUN05 -> PTO01: 16.60 km
# Distancia MUN05 -> MUN02: 0.81 km
# Distancia MUN05 -> MUN03: 9.52 km
# Distancia MUN05 -> MUN04: 11.67 km
# Distancia MUN05 -> MUN06: 8.89 km
# Distancia MUN05 -> MUN07: 6.87 km
# Distancia MUN05 -> MUN08: 13.23 km
# Distancia MUN05 -> MUN09: 9.65 km
# Distancia MUN05 -> MUN10: 6.53 km
# Distancia MUN05 -> MUN11: 5.35 km
# Distancia MUN05 -> MUN12: 9.07 km
# Distancia MUN05 -> MUN13: 16.84 km
# Distancia MUN05 -> MUN14: 4.58 km
# Distancia MUN05 -> MUN15: 13.72 km
# Distancia MUN05 -> MUN16: 0.34 km
# Distancia MUN05 -> MUN17: 5.53 km
# Distancia MUN05 -> MUN18: 3.26 km
# Distancia MUN05 -> MUN19: 6.46 km
# Distancia MUN05 -> MUN20: 12.41 km
# Distancia MUN05 -> MUN21: 15.98 km
# Distancia MUN05 -> MUN22: 17.68 km
# Distancia MUN05 -> MUN23: 2.55 km
# Distancia MUN05 -> MUN24: 14.21 km
# Distancia MUN05 -> MUN25: 4.44 km
# Distancia MUN06 -> PTO01: 10.62 km
# Distancia MUN06 -> MUN02: 9.20 km
# Distancia MUN06 -> MUN03: 10.80 km
# Distancia MUN06 -> MUN04: 9.31 km
# Distancia MUN06 -> MUN05: 8.89 km
# Distancia MUN06 -> MUN07: 5.09 km
# Distancia MUN06 -> MUN08: 16.71 km
# Distancia MUN06 -> MUN09: 0.83 km
# Distancia MUN06 -> MUN10: 4.78 km
# Distancia MUN06 -> MUN11: 13.05 km
# Distancia MUN06 -> MUN12: 6.50 km
# Distancia MUN06 -> MUN13: 13.89 km
# Distancia MUN06 -> MUN14: 7.51 km
# Distancia MUN06 -> MUN15: 9.83 km
# Distancia MUN06 -> MUN16: 9.22 km
# Distancia MUN06 -> MUN17: 11.73 km
# Distancia MUN06 -> MUN18: 5.73 km
# Distancia MUN06 -> MUN19: 4.53 km
# Distancia MUN06 -> MUN20: 14.24 km
# Distancia MUN06 -> MUN21: 11.90 km
# Distancia MUN06 -> MUN22: 18.97 km
# Distancia MUN06 -> MUN23: 9.00 km
# Distancia MUN06 -> MUN24: 10.65 km
# Distancia MUN06 -> MUN25: 8.96 km
# Distancia MUN07 -> PTO01: 9.73 km
# Distancia MUN07 -> MUN02: 7.54 km
# Distancia MUN07 -> MUN03: 5.77 km
# Distancia MUN07 -> MUN04: 5.48 km
# Distancia MUN07 -> MUN05: 6.87 km
# Distancia MUN07 -> MUN06: 5.09 km
# Distancia MUN07 -> MUN08: 11.62 km
# Distancia MUN07 -> MUN09: 5.85 km
# Distancia MUN07 -> MUN10: 7.34 km
# Distancia MUN07 -> MUN11: 12.13 km
# Distancia MUN07 -> MUN12: 10.08 km
# Distancia MUN07 -> MUN13: 10.70 km
# Distancia MUN07 -> MUN14: 3.19 km
# Distancia MUN07 -> MUN15: 7.09 km
# Distancia MUN07 -> MUN16: 7.09 km
# Distancia MUN07 -> MUN17: 11.70 km
# Distancia MUN07 -> MUN18: 5.16 km
# Distancia MUN07 -> MUN19: 0.76 km
# Distancia MUN07 -> MUN20: 9.26 km
# Distancia MUN07 -> MUN21: 9.40 km
# Distancia MUN07 -> MUN22: 14.21 km
# Distancia MUN07 -> MUN23: 5.56 km
# Distancia MUN07 -> MUN24: 7.72 km
# Distancia MUN07 -> MUN25: 9.43 km
# Distancia MUN08 -> PTO01: 15.43 km
# Distancia MUN08 -> MUN02: 13.96 km
# Distancia MUN08 -> MUN03: 6.02 km
# Distancia MUN08 -> MUN04: 9.51 km
# Distancia MUN08 -> MUN05: 13.23 km
# Distancia MUN08 -> MUN06: 16.71 km
# Distancia MUN08 -> MUN07: 11.62 km
# Distancia MUN08 -> MUN09: 17.46 km
# Distancia MUN08 -> MUN10: 17.98 km
# Distancia MUN08 -> MUN11: 17.32 km
# Distancia MUN08 -> MUN12: 20.91 km
# Distancia MUN08 -> MUN13: 10.97 km
# Distancia MUN08 -> MUN14: 10.06 km
# Distancia MUN08 -> MUN15: 11.50 km
# Distancia MUN08 -> MUN16: 13.10 km
# Distancia MUN08 -> MUN17: 18.46 km
# Distancia MUN08 -> MUN18: 14.54 km
# Distancia MUN08 -> MUN19: 12.24 km
# Distancia MUN08 -> MUN20: 3.23 km
# Distancia MUN08 -> MUN21: 12.33 km
# Distancia MUN08 -> MUN22: 5.46 km
# Distancia MUN08 -> MUN23: 10.75 km
# Distancia MUN08 -> MUN24: 11.12 km
# Distancia MUN08 -> MUN25: 17.65 km
# Distancia MUN09 -> PTO01: 10.65 km
# Distancia MUN09 -> MUN02: 9.92 km
# Distancia MUN09 -> MUN03: 11.52 km
# Distancia MUN09 -> MUN04: 9.82 km
# Distancia MUN09 -> MUN05: 9.65 km
# Distancia MUN09 -> MUN06: 0.83 km
# Distancia MUN09 -> MUN07: 5.85 km
# Distancia MUN09 -> MUN08: 17.46 km
# Distancia MUN09 -> MUN10: 5.11 km
# Distancia MUN09 -> MUN11: 13.66 km
# Distancia MUN09 -> MUN12: 6.46 km
# Distancia MUN09 -> MUN13: 14.24 km
# Distancia MUN09 -> MUN14: 8.34 km
# Distancia MUN09 -> MUN15: 10.16 km
# Distancia MUN09 -> MUN16: 9.98 km
# Distancia MUN09 -> MUN17: 12.25 km
# Distancia MUN09 -> MUN18: 6.45 km
# Distancia MUN09 -> MUN19: 5.32 km
# Distancia MUN09 -> MUN20: 14.94 km
# Distancia MUN09 -> MUN21: 12.16 km
# Distancia MUN09 -> MUN22: 19.59 km
# Distancia MUN09 -> MUN23: 9.82 km
# Distancia MUN09 -> MUN24: 11.00 km
# Distancia MUN09 -> MUN25: 9.47 km
# Distancia MUN10 -> PTO01: 15.24 km
# Distancia MUN10 -> MUN02: 6.41 km
# Distancia MUN10 -> MUN03: 12.72 km
# Distancia MUN10 -> MUN04: 12.70 km
# Distancia MUN10 -> MUN05: 6.53 km
# Distancia MUN10 -> MUN06: 4.78 km
# Distancia MUN10 -> MUN07: 7.34 km
# Distancia MUN10 -> MUN08: 17.98 km
# Distancia MUN10 -> MUN09: 5.11 km
# Distancia MUN10 -> MUN11: 9.09 km
# Distancia MUN10 -> MUN12: 2.92 km
# Distancia MUN10 -> MUN13: 17.75 km
# Distancia MUN10 -> MUN14: 7.92 km
# Distancia MUN10 -> MUN15: 13.83 km
# Distancia MUN10 -> MUN16: 6.86 km
# Distancia MUN10 -> MUN17: 7.37 km
# Distancia MUN10 -> MUN18: 3.65 km
# Distancia MUN10 -> MUN19: 6.58 km
# Distancia MUN10 -> MUN20: 16.19 km
# Distancia MUN10 -> MUN21: 16.06 km
# Distancia MUN10 -> MUN22: 21.35 km
# Distancia MUN10 -> MUN23: 7.97 km
# Distancia MUN10 -> MUN24: 14.59 km
# Distancia MUN10 -> MUN25: 4.61 km
# Distancia MUN11 -> PTO01: 21.83 km
# Distancia MUN11 -> MUN02: 4.61 km
# Distancia MUN11 -> MUN03: 14.60 km
# Distancia MUN11 -> MUN04: 17.02 km
# Distancia MUN11 -> MUN05: 5.35 km
# Distancia MUN11 -> MUN06: 13.05 km
# Distancia MUN11 -> MUN07: 12.13 km
# Distancia MUN11 -> MUN08: 17.32 km
# Distancia MUN11 -> MUN09: 13.66 km
# Distancia MUN11 -> MUN10: 9.09 km
# Distancia MUN11 -> MUN12: 10.43 km
# Distancia MUN11 -> MUN13: 22.17 km
# Distancia MUN11 -> MUN14: 9.90 km
# Distancia MUN11 -> MUN15: 19.06 km
# Distancia MUN11 -> MUN16: 5.22 km
# Distancia MUN11 -> MUN17: 2.33 km
# Distancia MUN11 -> MUN18: 7.53 km
# Distancia MUN11 -> MUN19: 11.64 km
# Distancia MUN11 -> MUN20: 17.14 km
# Distancia MUN11 -> MUN21: 21.33 km
# Distancia MUN11 -> MUN22: 22.26 km
# Distancia MUN11 -> MUN23: 7.58 km
# Distancia MUN11 -> MUN24: 19.57 km
# Distancia MUN11 -> MUN25: 4.56 km
# Distancia MUN12 -> PTO01: 17.09 km
# Distancia MUN12 -> MUN02: 8.79 km
# Distancia MUN12 -> MUN03: 15.60 km
# Distancia MUN12 -> MUN04: 15.29 km
# Distancia MUN12 -> MUN05: 9.07 km
# Distancia MUN12 -> MUN06: 6.50 km
# Distancia MUN12 -> MUN07: 10.08 km
# Distancia MUN12 -> MUN08: 20.91 km
# Distancia MUN12 -> MUN09: 6.46 km
# Distancia MUN12 -> MUN10: 2.92 km
# Distancia MUN12 -> MUN11: 10.43 km
# Distancia MUN12 -> MUN13: 20.19 km
# Distancia MUN12 -> MUN14: 10.85 km
# Distancia MUN12 -> MUN15: 16.18 km
# Distancia MUN12 -> MUN16: 9.38 km
# Distancia MUN12 -> MUN17: 8.31 km
# Distancia MUN12 -> MUN18: 6.50 km
# Distancia MUN12 -> MUN19: 9.33 km
# Distancia MUN12 -> MUN20: 19.08 km
# Distancia MUN12 -> MUN21: 18.33 km
# Distancia MUN12 -> MUN22: 24.21 km
# Distancia MUN12 -> MUN23: 10.78 km
# Distancia MUN12 -> MUN24: 16.97 km
# Distancia MUN12 -> MUN25: 5.94 km
# Distancia MUN13 -> PTO01: 5.94 km
# Distancia MUN13 -> MUN02: 17.62 km
# Distancia MUN13 -> MUN03: 8.15 km
# Distancia MUN13 -> MUN04: 5.25 km
# Distancia MUN13 -> MUN05: 16.84 km
# Distancia MUN13 -> MUN06: 13.89 km
# Distancia MUN13 -> MUN07: 10.70 km
# Distancia MUN13 -> MUN08: 10.97 km
# Distancia MUN13 -> MUN09: 14.24 km
# Distancia MUN13 -> MUN10: 17.75 km
# Distancia MUN13 -> MUN11: 22.17 km
# Distancia MUN13 -> MUN12: 20.19 km
# Distancia MUN13 -> MUN14: 12.26 km
# Distancia MUN13 -> MUN15: 4.07 km
# Distancia MUN13 -> MUN16: 16.95 km
# Distancia MUN13 -> MUN17: 22.17 km
# Distancia MUN13 -> MUN18: 15.84 km
# Distancia MUN13 -> MUN19: 11.41 km
# Distancia MUN13 -> MUN20: 8.00 km
# Distancia MUN13 -> MUN21: 2.50 km
# Distancia MUN13 -> MUN22: 8.60 km
# Distancia MUN13 -> MUN23: 14.66 km
# Distancia MUN13 -> MUN24: 3.24 km
# Distancia MUN13 -> MUN25: 20.08 km
# Distancia MUN14 -> PTO01: 12.49 km
# Distancia MUN14 -> MUN02: 5.37 km
# Distancia MUN14 -> MUN03: 5.20 km
# Distancia MUN14 -> MUN04: 7.13 km
# Distancia MUN14 -> MUN05: 4.58 km
# Distancia MUN14 -> MUN06: 7.51 km
# Distancia MUN14 -> MUN07: 3.19 km
# Distancia MUN14 -> MUN08: 10.06 km
# Distancia MUN14 -> MUN09: 8.34 km
# Distancia MUN14 -> MUN10: 7.92 km
# Distancia MUN14 -> MUN11: 9.90 km
# Distancia MUN14 -> MUN12: 10.85 km
# Distancia MUN14 -> MUN13: 12.26 km
# Distancia MUN14 -> MUN15: 9.29 km
# Distancia MUN14 -> MUN16: 4.68 km
# Distancia MUN14 -> MUN17: 10.01 km
# Distancia MUN14 -> MUN18: 4.56 km
# Distancia MUN14 -> MUN19: 3.27 km
# Distancia MUN14 -> MUN20: 8.46 km
# Distancia MUN14 -> MUN21: 11.50 km
# Distancia MUN14 -> MUN22: 13.74 km
# Distancia MUN14 -> MUN23: 2.57 km
# Distancia MUN14 -> MUN24: 9.72 km
# Distancia MUN14 -> MUN25: 8.31 km
# Distancia MUN15 -> PTO01: 4.00 km
# Distancia MUN15 -> MUN02: 14.45 km
# Distancia MUN15 -> MUN03: 6.66 km
# Distancia MUN15 -> MUN04: 2.46 km
# Distancia MUN15 -> MUN05: 13.72 km
# Distancia MUN15 -> MUN06: 9.83 km
# Distancia MUN15 -> MUN07: 7.09 km
# Distancia MUN15 -> MUN08: 11.50 km
# Distancia MUN15 -> MUN09: 10.16 km
# Distancia MUN15 -> MUN10: 13.83 km
# Distancia MUN15 -> MUN11: 19.06 km
# Distancia MUN15 -> MUN12: 16.18 km
# Distancia MUN15 -> MUN13: 4.07 km
# Distancia MUN15 -> MUN14: 9.29 km
# Distancia MUN15 -> MUN16: 13.88 km
# Distancia MUN15 -> MUN17: 18.78 km
# Distancia MUN15 -> MUN18: 12.24 km
# Distancia MUN15 -> MUN19: 7.73 km
# Distancia MUN15 -> MUN20: 8.28 km
# Distancia MUN15 -> MUN21: 2.30 km
# Distancia MUN15 -> MUN22: 11.03 km
# Distancia MUN15 -> MUN23: 11.83 km
# Distancia MUN15 -> MUN24: 0.85 km
# Distancia MUN15 -> MUN25: 16.51 km
# Distancia MUN16 -> PTO01: 16.81 km
# Distancia MUN16 -> MUN02: 0.86 km
# Distancia MUN16 -> MUN03: 9.53 km
# Distancia MUN16 -> MUN04: 11.80 km
# Distancia MUN16 -> MUN05: 0.34 km
# Distancia MUN16 -> MUN06: 9.22 km
# Distancia MUN16 -> MUN07: 7.09 km
# Distancia MUN16 -> MUN08: 13.10 km
# Distancia MUN16 -> MUN09: 9.98 km
# Distancia MUN16 -> MUN10: 6.86 km
# Distancia MUN16 -> MUN11: 5.22 km
# Distancia MUN16 -> MUN12: 9.38 km
# Distancia MUN16 -> MUN13: 16.95 km
# Distancia MUN16 -> MUN14: 4.68 km
# Distancia MUN16 -> MUN15: 13.88 km
# Distancia MUN16 -> MUN17: 5.54 km
# Distancia MUN16 -> MUN18: 3.61 km
# Distancia MUN16 -> MUN19: 6.71 km
# Distancia MUN16 -> MUN20: 12.36 km
# Distancia MUN16 -> MUN21: 16.13 km
# Distancia MUN16 -> MUN22: 17.61 km
# Distancia MUN16 -> MUN23: 2.50 km
# Distancia MUN16 -> MUN24: 14.36 km
# Distancia MUN16 -> MUN25: 4.62 km
# Distancia MUN17 -> PTO01: 21.21 km
# Distancia MUN17 -> MUN02: 4.72 km
# Distancia MUN17 -> MUN03: 15.04 km
# Distancia MUN17 -> MUN04: 16.93 km
# Distancia MUN17 -> MUN05: 5.53 km
# Distancia MUN17 -> MUN06: 11.73 km
# Distancia MUN17 -> MUN07: 11.70 km
# Distancia MUN17 -> MUN08: 18.46 km
# Distancia MUN17 -> MUN09: 12.25 km
# Distancia MUN17 -> MUN10: 7.37 km
# Distancia MUN17 -> MUN11: 2.33 km
# Distancia MUN17 -> MUN12: 8.31 km
# Distancia MUN17 -> MUN13: 22.17 km
# Distancia MUN17 -> MUN14: 10.01 km
# Distancia MUN17 -> MUN15: 18.78 km
# Distancia MUN17 -> MUN16: 5.54 km
# Distancia MUN17 -> MUN18: 6.67 km
# Distancia MUN17 -> MUN19: 11.11 km
# Distancia MUN17 -> MUN20: 17.90 km
# Distancia MUN17 -> MUN21: 21.08 km
# Distancia MUN17 -> MUN22: 23.13 km
# Distancia MUN17 -> MUN23: 8.05 km
# Distancia MUN17 -> MUN24: 19.37 km
# Distancia MUN17 -> MUN25: 2.79 km
# Distancia MUN18 -> PTO01: 14.53 km
# Distancia MUN18 -> MUN02: 3.48 km
# Distancia MUN18 -> MUN03: 9.67 km
# Distancia MUN18 -> MUN04: 10.59 km
# Distancia MUN18 -> MUN05: 3.26 km
# Distancia MUN18 -> MUN06: 5.73 km
# Distancia MUN18 -> MUN07: 5.16 km
# Distancia MUN18 -> MUN08: 14.54 km
# Distancia MUN18 -> MUN09: 6.45 km
# Distancia MUN18 -> MUN10: 3.65 km
# Distancia MUN18 -> MUN11: 7.53 km
# Distancia MUN18 -> MUN12: 6.50 km
# Distancia MUN18 -> MUN13: 15.84 km
# Distancia MUN18 -> MUN14: 4.56 km
# Distancia MUN18 -> MUN15: 12.24 km
# Distancia MUN18 -> MUN16: 3.61 km
# Distancia MUN18 -> MUN17: 6.67 km
# Distancia MUN18 -> MUN19: 4.51 km
# Distancia MUN18 -> MUN20: 13.02 km
# Distancia MUN18 -> MUN21: 14.54 km
# Distancia MUN18 -> MUN22: 18.28 km
# Distancia MUN18 -> MUN23: 4.32 km
# Distancia MUN18 -> MUN24: 12.88 km
# Distancia MUN18 -> MUN25: 4.27 km
# Distancia MUN19 -> PTO01: 10.19 km
# Distancia MUN19 -> MUN02: 7.09 km
# Distancia MUN19 -> MUN03: 6.46 km
# Distancia MUN19 -> MUN04: 6.21 km
# Distancia MUN19 -> MUN05: 6.46 km
# Distancia MUN19 -> MUN06: 4.53 km
# Distancia MUN19 -> MUN07: 0.76 km
# Distancia MUN19 -> MUN08: 12.24 km
# Distancia MUN19 -> MUN09: 5.32 km
# Distancia MUN19 -> MUN10: 6.58 km
# Distancia MUN19 -> MUN11: 11.64 km
# Distancia MUN19 -> MUN12: 9.33 km
# Distancia MUN19 -> MUN13: 11.41 km
# Distancia MUN19 -> MUN14: 3.27 km
# Distancia MUN19 -> MUN15: 7.73 km
# Distancia MUN19 -> MUN16: 6.71 km
# Distancia MUN19 -> MUN17: 11.11 km
# Distancia MUN19 -> MUN18: 4.51 km
# Distancia MUN19 -> MUN20: 9.95 km
# Distancia MUN19 -> MUN21: 10.04 km
# Distancia MUN19 -> MUN22: 14.94 km
# Distancia MUN19 -> MUN23: 5.42 km
# Distancia MUN19 -> MUN24: 8.39 km
# Distancia MUN19 -> MUN25: 8.78 km
# Distancia MUN20 -> PTO01: 12.21 km
# Distancia MUN20 -> MUN02: 13.21 km
# Distancia MUN20 -> MUN03: 3.50 km
# Distancia MUN20 -> MUN04: 6.35 km
# Distancia MUN20 -> MUN05: 12.41 km
# Distancia MUN20 -> MUN06: 14.24 km
# Distancia MUN20 -> MUN07: 9.26 km
# Distancia MUN20 -> MUN08: 3.23 km
# Distancia MUN20 -> MUN09: 14.94 km
# Distancia MUN20 -> MUN10: 16.19 km
# Distancia MUN20 -> MUN11: 17.14 km
# Distancia MUN20 -> MUN12: 19.08 km
# Distancia MUN20 -> MUN13: 8.00 km
# Distancia MUN20 -> MUN14: 8.46 km
# Distancia MUN20 -> MUN15: 8.28 km
# Distancia MUN20 -> MUN16: 12.36 km
# Distancia MUN20 -> MUN17: 17.90 km
# Distancia MUN20 -> MUN18: 13.02 km
# Distancia MUN20 -> MUN19: 9.95 km
# Distancia MUN20 -> MUN21: 9.15 km
# Distancia MUN20 -> MUN22: 5.29 km
# Distancia MUN20 -> MUN23: 9.87 km
# Distancia MUN20 -> MUN24: 7.90 km
# Distancia MUN20 -> MUN25: 16.63 km
# Distancia MUN21 -> PTO01: 3.53 km
# Distancia MUN21 -> MUN02: 16.73 km
# Distancia MUN21 -> MUN03: 8.31 km
# Distancia MUN21 -> MUN04: 4.44 km
# Distancia MUN21 -> MUN05: 15.98 km
# Distancia MUN21 -> MUN06: 11.90 km
# Distancia MUN21 -> MUN07: 9.40 km
# Distancia MUN21 -> MUN08: 12.33 km
# Distancia MUN21 -> MUN09: 12.16 km
# Distancia MUN21 -> MUN10: 16.06 km
# Distancia MUN21 -> MUN11: 21.33 km
# Distancia MUN21 -> MUN12: 18.33 km
# Distancia MUN21 -> MUN13: 2.50 km
# Distancia MUN21 -> MUN14: 11.50 km
# Distancia MUN21 -> MUN15: 2.30 km
# Distancia MUN21 -> MUN16: 16.13 km
# Distancia MUN21 -> MUN17: 21.08 km
# Distancia MUN21 -> MUN18: 14.54 km
# Distancia MUN21 -> MUN19: 10.04 km
# Distancia MUN21 -> MUN20: 9.15 km
# Distancia MUN21 -> MUN22: 10.78 km
# Distancia MUN21 -> MUN23: 14.02 km
# Distancia MUN21 -> MUN24: 1.79 km
# Distancia MUN21 -> MUN25: 18.81 km
# Distancia MUN22 -> PTO01: 14.30 km
# Distancia MUN22 -> MUN02: 18.46 km
# Distancia MUN22 -> MUN03: 8.64 km
# Distancia MUN22 -> MUN04: 10.03 km
# Distancia MUN22 -> MUN05: 17.68 km
# Distancia MUN22 -> MUN06: 18.97 km
# Distancia MUN22 -> MUN07: 14.21 km
# Distancia MUN22 -> MUN08: 5.46 km
# Distancia MUN22 -> MUN09: 19.59 km
# Distancia MUN22 -> MUN10: 21.35 km
# Distancia MUN22 -> MUN11: 22.26 km
# Distancia MUN22 -> MUN12: 24.21 km
# Distancia MUN22 -> MUN13: 8.60 km
# Distancia MUN22 -> MUN14: 13.74 km
# Distancia MUN22 -> MUN15: 11.03 km
# Distancia MUN22 -> MUN16: 17.61 km
# Distancia MUN22 -> MUN17: 23.13 km
# Distancia MUN22 -> MUN18: 18.28 km
# Distancia MUN22 -> MUN19: 14.94 km
# Distancia MUN22 -> MUN20: 5.29 km
# Distancia MUN22 -> MUN21: 10.78 km
# Distancia MUN22 -> MUN23: 15.13 km
# Distancia MUN22 -> MUN24: 10.33 km
# Distancia MUN22 -> MUN25: 21.92 km
# Distancia MUN23 -> PTO01: 15.05 km
# Distancia MUN23 -> MUN02: 3.34 km
# Distancia MUN23 -> MUN03: 7.05 km
# Distancia MUN23 -> MUN04: 9.61 km
# Distancia MUN23 -> MUN05: 2.55 km
# Distancia MUN23 -> MUN06: 9.00 km
# Distancia MUN23 -> MUN07: 5.56 km
# Distancia MUN23 -> MUN08: 10.75 km
# Distancia MUN23 -> MUN09: 9.82 km
# Distancia MUN23 -> MUN10: 7.97 km
# Distancia MUN23 -> MUN11: 7.58 km
# Distancia MUN23 -> MUN12: 10.78 km
# Distancia MUN23 -> MUN13: 14.66 km
# Distancia MUN23 -> MUN14: 2.57 km
# Distancia MUN23 -> MUN15: 11.83 km
# Distancia MUN23 -> MUN16: 2.50 km
# Distancia MUN23 -> MUN17: 8.05 km
# Distancia MUN23 -> MUN18: 4.32 km
# Distancia MUN23 -> MUN19: 5.42 km
# Distancia MUN23 -> MUN20: 9.87 km
# Distancia MUN23 -> MUN21: 14.02 km
# Distancia MUN23 -> MUN22: 15.13 km
# Distancia MUN23 -> MUN24: 12.24 km
# Distancia MUN23 -> MUN25: 6.89 km
# Distancia MUN24 -> PTO01: 4.31 km
# Distancia MUN24 -> MUN02: 14.97 km
# Distancia MUN24 -> MUN03: 6.64 km
# Distancia MUN24 -> MUN04: 2.65 km
# Distancia MUN24 -> MUN05: 14.21 km
# Distancia MUN24 -> MUN06: 10.65 km
# Distancia MUN24 -> MUN07: 7.72 km
# Distancia MUN24 -> MUN08: 11.12 km
# Distancia MUN24 -> MUN09: 11.00 km
# Distancia MUN24 -> MUN10: 14.59 km
# Distancia MUN24 -> MUN11: 19.57 km
# Distancia MUN24 -> MUN12: 16.97 km
# Distancia MUN24 -> MUN13: 3.24 km
# Distancia MUN24 -> MUN14: 9.72 km
# Distancia MUN24 -> MUN15: 0.85 km
# Distancia MUN24 -> MUN16: 14.36 km
# Distancia MUN24 -> MUN17: 19.37 km
# Distancia MUN24 -> MUN18: 12.88 km
# Distancia MUN24 -> MUN19: 8.39 km
# Distancia MUN24 -> MUN20: 7.90 km
# Distancia MUN24 -> MUN21: 1.79 km
# Distancia MUN24 -> MUN22: 10.33 km
# Distancia MUN24 -> MUN23: 12.24 km
# Distancia MUN24 -> MUN25: 17.15 km
# Distancia MUN25 -> PTO01: 18.69 km
# Distancia MUN25 -> MUN02: 3.79 km
# Distancia MUN25 -> MUN03: 13.49 km
# Distancia MUN25 -> MUN04: 14.83 km
# Distancia MUN25 -> MUN05: 4.44 km
# Distancia MUN25 -> MUN06: 8.96 km
# Distancia MUN25 -> MUN07: 9.43 km
# Distancia MUN25 -> MUN08: 17.65 km
# Distancia MUN25 -> MUN09: 9.47 km
# Distancia MUN25 -> MUN10: 4.61 km
# Distancia MUN25 -> MUN11: 4.56 km
# Distancia MUN25 -> MUN12: 5.94 km
# Distancia MUN25 -> MUN13: 20.08 km
# Distancia MUN25 -> MUN14: 8.31 km
# Distancia MUN25 -> MUN15: 16.51 km
# Distancia MUN25 -> MUN16: 4.62 km
# Distancia MUN25 -> MUN17: 2.79 km
# Distancia MUN25 -> MUN18: 4.27 km
# Distancia MUN25 -> MUN19: 8.78 km
# Distancia MUN25 -> MUN20: 16.63 km
# Distancia MUN25 -> MUN21: 18.81 km
# Distancia MUN25 -> MUN22: 21.92 km
# Distancia MUN25 -> MUN23: 6.89 km
# Distancia MUN25 -> MUN24: 17.15 km
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write C:\Users\MARIAN~1\AppData\Local\Temp\tmpv10rv7ou.glpk.raw --wglp
#  C:\Users\MARIAN~1\AppData\Local\Temp\tmpb9lufdht.glpk.glp --cpxlp C:\Users\MARIAN~1\AppData\Local\Temp\tmp8xde_526.pyomo.lp
# Reading problem data from 'C:\Users\MARIAN~1\AppData\Local\Temp\tmp8xde_526.pyomo.lp'...
# C:\Users\MARIAN~1\AppData\Local\Temp\tmp8xde_526.pyomo.lp:35530: warning: lower bound of variable 'x2' redefined
# C:\Users\MARIAN~1\AppData\Local\Temp\tmp8xde_526.pyomo.lp:35530: warning: upper bound of variable 'x2' redefined
# 448 rows, 4992 columns, 24384 non-zeros
# 4800 integer variables, all of which are binary
# 40330 lines were read
# Writing problem data to 'C:\Users\MARIAN~1\AppData\Local\Temp\tmpb9lufdht.glpk.glp'...
# 35067 lines were written
# GLPK Integer Optimizer, v4.65
# 448 rows, 4992 columns, 24384 non-zeros
# 4800 integer variables, all of which are binary
# Preprocessing...
# 448 rows, 4992 columns, 24384 non-zeros
# 4800 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  3.444e-01  max|aij| =  2.500e+01  ratio =  7.259e+01
# GM: min|aij| =  3.714e-01  max|aij| =  2.693e+00  ratio =  7.251e+00
# EQ: min|aij| =  1.391e-01  max|aij| =  1.000e+00  ratio =  7.188e+00
# 2N: min|aij| =  8.610e-02  max|aij| =  1.625e+00  ratio =  1.887e+01
# Constructing initial basis...
# Size of triangular part is 410
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 448 rows, 4992 columns, 24384 non-zeros
#       0: obj =   2.654244682e+06 inf =   8.500e+02 (28)
#     210: obj =   1.174070297e+06 inf =   2.882e-13 (0)
# Perturbing LP to avoid stalling [428]...
# Removing LP perturbation [462]...
# *   462: obj =   8.620375033e+05 inf =   0.000e+00 (0) 2
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   462: mip =     not found yet >=              -inf        (1; 0)
# +   463: >>>>>   8.620375033e+05 >=   8.620375033e+05 < 0.1% (2; 0)
# +   463: mip =   8.620375033e+05 >=     tree is empty   0.0% (0; 3)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 6.5 Mb (6836452 bytes)
# Writing MIP solution to 'C:\Users\MARIAN~1\AppData\Local\Temp\tmpv10rv7ou.glpk.raw'...
# 5449 lines were written
#
# ¡Solución encontrada!
# Costo total: $862037.50 COP
#
# Ruta del vehículo 1:
# PTO01 -> MUN04 -> PTO01
# Distancia total: 12.76 km
# Carga total: 12.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 2:
# PTO01 -> MUN13 -> PTO01
# Distancia total: 11.88 km
# Carga total: 12.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 3:
# PTO01 -> MUN15 -> PTO01
# Distancia total: 8.01 km
# Carga total: 15.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 4:
# PTO01 -> MUN24 -> PTO01
# Distancia total: 8.62 km
# Carga total: 15.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 5:
# PTO01 -> MUN03 -> PTO01
# Distancia total: 21.24 km
# Carga total: 15.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 6:
# PTO01 -> MUN07 -> PTO01
# Distancia total: 19.46 km
# Carga total: 17.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 7:
# PTO01 -> MUN19 -> PTO01
# Distancia total: 20.38 km
# Carga total: 12.0 unidades
# Detalle de entregas:
#
# Ruta del vehículo 8:
# PTO01 -> MUN21 -> PTO01
# Distancia total: 7.06 km
# Carga total: 15.0 unidades
# Detalle de entregas:
